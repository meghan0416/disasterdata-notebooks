# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import joblib

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import StratifiedKFold, HalvingGridSearchCV
from sklearn.svm import LinearSVC
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
# Read the label encoder and the train-test splits from the other notebook

X_train, y_train, X_test, y_test = joblib.load('/content/drive/MyDrive/notebook_data/exports/train_test/train_test_split_v4.pkl')
label_encoder = joblib.load('/content/drive/MyDrive/notebook_data/exports/labelEncoder_tfidfVectorizer/label_encoder_v4.pkl')

# %%
print(f"Training with {X_train.shape[0]} samples; Testing with {X_test.shape[0]} samples")
print(f"Labels before conversion: {np.unique(label_encoder.inverse_transform(y_train))}")
print(f"Labels after conversion: {np.unique(y_train)}")
# Out:
# Training with 20048 samples; Testing with 5013 samples
# Labels before conversion: ['earthquake' 'flood' 'hurricane' 'other' 'tornado' 'wildfire']
# Labels after conversion: [0 1 2 3 4 5]

# %%
X_train.head()
# Out:
# 21669    i do nt know how i held a job before i did nt ...
# 9094     1156 j1 hd now playing ayabie natsumonogatari ...
# 18799    climate change parching the american west even...
# 16642                              hollywood or washington
# 9156     unless its your own business nobody should be ...
# Name: cleaned, dtype: object

# %%
# Create the pipeline
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('clf', OneVsRestClassifier(LinearSVC(class_weight='balanced')))
])

# %%
param_grid = {
    'tfidf__ngram_range': [(1,3)],
    'tfidf__max_df': [0.9],
    'tfidf__min_df': [2, 4],
    'tfidf__max_features': [7500],
    'tfidf__stop_words': [None, 'english'],
    'clf__estimator__C': [0.6],
    'clf__estimator__tol': [1e-3, 1e-4, 1e-5],
    'clf__estimator__max_iter': [800],
    'clf__estimator__intercept_scaling': [0.75, 10, 20]
}

# %%
# set up the grid search
kfolds = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
grid_search = HalvingGridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    cv=kfolds,
    n_jobs=-1,
    verbose=1,
    scoring='f1_weighted',
    factor=2,
    error_score="raise"
)

# %%
# fit to the data
grid_search.fit(X_train, y_train)
# Out:
# n_iterations: 6
# n_required_iterations: 6
# n_possible_iterations: 6
# min_resources_: 626
# max_resources_: 20048
# aggressive_elimination: False
# factor: 2
# ----------
# iter: 0
# n_candidates: 36
# n_resources: 626
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# ----------
# iter: 1
# n_candidates: 18
# n_resources: 1252
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# ----------
# iter: 2
# n_candidates: 9
# n_resources: 2504
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# ----------
# iter: 3
# n_candidates: 5
# n_resources: 5008
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ----------
# iter: 4
# n_candidates: 3
# n_resources: 10016
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# ----------
# iter: 5
# n_candidates: 2
# n_resources: 20032
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# HalvingGridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#                     error_score='raise',
#                     estimator=Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                                               ('clf',
#                                                OneVsRestClassifier(estimator=LinearSVC(class_weight='balanced')))]),
#                     factor=2, n_jobs=-1,
#                     param_grid={'clf__estimator__C': [0.6],
#                                 'clf__estimator__intercept_scaling': [0.75, 10,
#                                                                       20],
#                                 'clf__estimator__max_iter': [800],
#                                 'clf__estimator__tol': [0.001, 0.0001, 1e-05],
#                                 'tfidf__max_df': [0.9],
#                                 'tfidf__max_features': [7500],
#                                 'tfidf__min_df': [2, 4],
#                                 'tfidf__ngram_range': [(1, 3)],
#                                 'tfidf__stop_words': [None, 'english']},
#                     scoring='f1_weighted', verbose=1)

# %%
print(f"Best parameters: {grid_search.best_params_}")
print(f"Best score: {grid_search.best_score_}")
# Out:
# Best parameters: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Best score: 0.9004622683727111

# %%
best_estimator = grid_search.best_estimator_
y_pred = best_estimator.predict(X_test)
# convert them back to the labels we can understand
y_pred_text = label_encoder.inverse_transform(y_pred)
y_test_text = label_encoder.inverse_transform(y_test)
print(classification_report(y_test_text, y_pred_text), confusion_matrix(y_test_text, y_pred_text))
# Out:
#               precision    recall  f1-score   support
#
#   earthquake       0.97      0.98      0.98      1131
#        flood       0.92      0.92      0.92       663
#    hurricane       0.95      0.95      0.95       949
#        other       0.75      0.76      0.76       995
#      tornado       0.88      0.84      0.86       153
#     wildfire       0.86      0.84      0.85      1122
#
#     accuracy                           0.89      5013
#    macro avg       0.89      0.88      0.88      5013
# weighted avg       0.89      0.89      0.89      5013
#  [[1112    0    0   15    1    3]
#  [   2  607   12   35    2    5]
#  [   0   16  897   24    4    8]
#  [  31   29   29  761    7  138]
#  [   1    2    2   18  128    2]
#  [   1    5    8  167    3  938]]

# %%
cv_results = grid_search.cv_results_

# Print mean training and validation scores for each parameter set
for mean_train, mean_val, params in zip(cv_results["mean_train_score"], cv_results["mean_test_score"], cv_results["params"]):
    print(f"Params: {params}")
    print(f"Train Score: {mean_train:.4f} | Validation Score: {mean_val:.4f}\n")

print("Best Validation Score:", grid_search.best_score_)
# Out:
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': None}
# Train Score: 0.9968 | Validation Score: 0.7987
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9944 | Validation Score: 0.8237
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': None}
# Train Score: 0.9896 | Validation Score: 0.8093
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9808 | Validation Score: 0.8411
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': None}
# Train Score: 0.9968 | Validation Score: 0.7987
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9944 | Validation Score: 0.8237
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': None}
# Train Score: 0.9896 | Validation Score: 0.8093
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9808 | Validation Score: 0.8411
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 1e-05, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': None}
# Train Score: 0.9968 | Validation Score: 0.7987
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 1e-05, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9944 | Validation Score: 0.8237
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 1e-05, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': None}
# Train Score: 0.9896 | Validation Score: 0.8093
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 1e-05, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9808 | Validation Score: 0.8411
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': None}
# Train Score: 0.9968 | Validation Score: 0.7964
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9944 | Validation Score: 0.8253
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': None}
# Train Score: 0.9896 | Validation Score: 0.8077
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9804 | Validation Score: 0.8397
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': None}
# Train Score: 0.9968 | Validation Score: 0.7964
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9944 | Validation Score: 0.8237
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': None}
# Train Score: 0.9900 | Validation Score: 0.8077
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9804 | Validation Score: 0.8396
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 1e-05, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': None}
# Train Score: 0.9968 | Validation Score: 0.7964
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 1e-05, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9944 | Validation Score: 0.8237
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 1e-05, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': None}
# Train Score: 0.9900 | Validation Score: 0.8083
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 1e-05, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9804 | Validation Score: 0.8396
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': None}
# Train Score: 0.9948 | Validation Score: 0.8032
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9928 | Validation Score: 0.8193
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': None}
# Train Score: 0.9856 | Validation Score: 0.8102
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9724 | Validation Score: 0.8400
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': None}
# Train Score: 0.9956 | Validation Score: 0.8032
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9932 | Validation Score: 0.8237
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': None}
# Train Score: 0.9860 | Validation Score: 0.8038
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9743 | Validation Score: 0.8388
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 1e-05, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': None}
# Train Score: 0.9952 | Validation Score: 0.7924
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 1e-05, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9928 | Validation Score: 0.8194
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 1e-05, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': None}
# Train Score: 0.9836 | Validation Score: 0.8065
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 1e-05, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9692 | Validation Score: 0.8347
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9902 | Validation Score: 0.8403
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 1e-05, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9900 | Validation Score: 0.8406
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9926 | Validation Score: 0.8420
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9926 | Validation Score: 0.8420
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 1e-05, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9926 | Validation Score: 0.8420
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9898 | Validation Score: 0.8408
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 1e-05, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9926 | Validation Score: 0.8420
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9926 | Validation Score: 0.8420
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9926 | Validation Score: 0.8420
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 1e-05, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9792 | Validation Score: 0.8383
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9794 | Validation Score: 0.8405
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9832 | Validation Score: 0.8365
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 1e-05, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9834 | Validation Score: 0.8365
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9834 | Validation Score: 0.8365
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9792 | Validation Score: 0.8392
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9834 | Validation Score: 0.8372
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 1e-05, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9834 | Validation Score: 0.8372
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9834 | Validation Score: 0.8372
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9754 | Validation Score: 0.8595
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 1e-05, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9879 | Validation Score: 0.8573
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9886 | Validation Score: 0.8600
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9917 | Validation Score: 0.8641
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 1e-05, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9917 | Validation Score: 0.8641
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9917 | Validation Score: 0.8641
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9917 | Validation Score: 0.8641
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9917 | Validation Score: 0.8641
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 1e-05, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9917 | Validation Score: 0.8641
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9855 | Validation Score: 0.8822
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9855 | Validation Score: 0.8822
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9855 | Validation Score: 0.8819
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 1e-05, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9855 | Validation Score: 0.8822
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9855 | Validation Score: 0.8821
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9780 | Validation Score: 0.8879
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9780 | Validation Score: 0.8879
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 1e-05, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9780 | Validation Score: 0.8879
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 0.0001, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9662 | Validation Score: 0.9005
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'clf__estimator__tol': 1e-05, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3), 'tfidf__stop_words': 'english'}
# Train Score: 0.9662 | Validation Score: 0.9005
#
# Best Validation Score: 0.9004622683727111

# %%
# export model
joblib.dump((best_estimator, label_encoder), '/content/drive/MyDrive/notebook_data/exports/models/linearsvc/linsvc_model_encoder_stopwords_nofeatures.pkl')
# Out:
# ['/content/drive/MyDrive/notebook_data/exports/models/linearsvc/linsvc_model_encoder_stopwords_nofeatures.pkl']

# %%
param_grid = {
    'tfidf__ngram_range': [(1,3)],
    'tfidf__max_df': [0.9],
    'tfidf__min_df': [2, 4],
    'tfidf__max_features': [7500],
    'clf__estimator__C': [0.6, 0.8, 1, 10],
    'clf__estimator__max_iter': [800],
    'clf__estimator__intercept_scaling': [0.75, 2, 10, 20]
}

# %%
# set up the grid search
kfolds = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
grid_search_2 = HalvingGridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    cv=kfolds,
    n_jobs=-1,
    verbose=1,
    scoring='f1_weighted',
    factor=2,
    error_score="raise"
)

# %%
# fit to the data
grid_search_2.fit(X_train, y_train)
# Out:
# n_iterations: 6
# n_required_iterations: 6
# n_possible_iterations: 6
# min_resources_: 626
# max_resources_: 20048
# aggressive_elimination: False
# factor: 2
# ----------
# iter: 0
# n_candidates: 32
# n_resources: 626
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# ----------
# iter: 1
# n_candidates: 16
# n_resources: 1252
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# ----------
# iter: 2
# n_candidates: 8
# n_resources: 2504
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# ----------
# iter: 3
# n_candidates: 4
# n_resources: 5008
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# ----------
# iter: 4
# n_candidates: 2
# n_resources: 10016
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# ----------
# iter: 5
# n_candidates: 1
# n_resources: 20032
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# HalvingGridSearchCV(cv=StratifiedKFold(n_splits=3, random_state=42, shuffle=True),
#                     error_score='raise',
#                     estimator=Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                                               ('clf',
#                                                OneVsRestClassifier(estimator=LinearSVC(class_weight='balanced')))]),
#                     factor=2, n_jobs=-1,
#                     param_grid={'clf__estimator__C': [0.6, 0.8, 1, 10],
#                                 'clf__estimator__intercept_scaling': [0.75, 2,
#                                                                       10, 20],
#                                 'clf__estimator__max_iter': [800],
#                                 'tfidf__max_df': [0.9],
#                                 'tfidf__max_features': [7500],
#                                 'tfidf__min_df': [2, 4],
#                                 'tfidf__ngram_range': [(1, 3)]},
#                     scoring='f1_weighted', verbose=1)

# %%
print(f"Best parameters: {grid_search_2.best_params_}")
print(f"Best score: {grid_search_2.best_score_}")
# Out:
# Best parameters: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 2, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Best score: 0.9039917282864786

# %%
best_estimator_2 = grid_search_2.best_estimator_
y_pred = best_estimator_2.predict(X_test)
# convert them back to the labels we can understand
y_pred_text = label_encoder.inverse_transform(y_pred)
y_test_text = label_encoder.inverse_transform(y_test)
print(classification_report(y_test_text, y_pred_text), confusion_matrix(y_test_text, y_pred_text))
# Out:
#               precision    recall  f1-score   support
#
#   earthquake       0.97      0.98      0.97      1131
#        flood       0.93      0.90      0.91       663
#    hurricane       0.94      0.94      0.94       949
#        other       0.74      0.79      0.77       995
#      tornado       0.90      0.84      0.87       153
#     wildfire       0.88      0.85      0.87      1122
#
#     accuracy                           0.89      5013
#    macro avg       0.89      0.88      0.89      5013
# weighted avg       0.89      0.89      0.89      5013
#  [[1105    0    1   21    1    3]
#  [   2  594   15   46    3    3]
#  [   0   11  895   33    4    6]
#  [  29   31   28  787    5  115]
#  [   0    1    3   18  128    3]
#  [   1    4    7  152    1  957]]

# %%
cv_results_2 = grid_search_2.cv_results_

# Print mean training and validation scores for each parameter set
for mean_train, mean_val, params in zip(cv_results_2["mean_train_score"], cv_results_2["mean_test_score"], cv_results_2["params"]):
    print(f"Params: {params}")
    print(f"Train Score: {mean_train:.4f} | Validation Score: {mean_val:.4f}\n")

print("Best Validation Score:", grid_search_2.best_score_)
# Out:
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9960 | Validation Score: 0.7788
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9896 | Validation Score: 0.7935
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 2, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9960 | Validation Score: 0.7789
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 2, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9896 | Validation Score: 0.7923
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9960 | Validation Score: 0.7789
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9896 | Validation Score: 0.7920
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9944 | Validation Score: 0.7779
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9856 | Validation Score: 0.8008
#
# Params: {'clf__estimator__C': 0.8, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9976 | Validation Score: 0.7768
#
# Params: {'clf__estimator__C': 0.8, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9912 | Validation Score: 0.7943
#
# Params: {'clf__estimator__C': 0.8, 'clf__estimator__intercept_scaling': 2, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9976 | Validation Score: 0.7769
#
# Params: {'clf__estimator__C': 0.8, 'clf__estimator__intercept_scaling': 2, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9912 | Validation Score: 0.7945
#
# Params: {'clf__estimator__C': 0.8, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9976 | Validation Score: 0.7769
#
# Params: {'clf__estimator__C': 0.8, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9912 | Validation Score: 0.7945
#
# Params: {'clf__estimator__C': 0.8, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9960 | Validation Score: 0.7734
#
# Params: {'clf__estimator__C': 0.8, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9840 | Validation Score: 0.7901
#
# Params: {'clf__estimator__C': 1, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9984 | Validation Score: 0.7741
#
# Params: {'clf__estimator__C': 1, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9936 | Validation Score: 0.7924
#
# Params: {'clf__estimator__C': 1, 'clf__estimator__intercept_scaling': 2, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9984 | Validation Score: 0.7754
#
# Params: {'clf__estimator__C': 1, 'clf__estimator__intercept_scaling': 2, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9928 | Validation Score: 0.7912
#
# Params: {'clf__estimator__C': 1, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9984 | Validation Score: 0.7755
#
# Params: {'clf__estimator__C': 1, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9936 | Validation Score: 0.7928
#
# Params: {'clf__estimator__C': 1, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9976 | Validation Score: 0.7781
#
# Params: {'clf__estimator__C': 1, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9888 | Validation Score: 0.7857
#
# Params: {'clf__estimator__C': 10, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9992 | Validation Score: 0.7692
#
# Params: {'clf__estimator__C': 10, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9992 | Validation Score: 0.7617
#
# Params: {'clf__estimator__C': 10, 'clf__estimator__intercept_scaling': 2, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9992 | Validation Score: 0.7666
#
# Params: {'clf__estimator__C': 10, 'clf__estimator__intercept_scaling': 2, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9992 | Validation Score: 0.7619
#
# Params: {'clf__estimator__C': 10, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9992 | Validation Score: 0.7682
#
# Params: {'clf__estimator__C': 10, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9992 | Validation Score: 0.7737
#
# Params: {'clf__estimator__C': 10, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9976 | Validation Score: 0.7821
#
# Params: {'clf__estimator__C': 10, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9904 | Validation Score: 0.7629
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9960 | Validation Score: 0.8159
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9960 | Validation Score: 0.8151
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 2, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9960 | Validation Score: 0.8168
#
# Params: {'clf__estimator__C': 10, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9968 | Validation Score: 0.8127
#
# Params: {'clf__estimator__C': 1, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9892 | Validation Score: 0.8123
#
# Params: {'clf__estimator__C': 0.8, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9876 | Validation Score: 0.8118
#
# Params: {'clf__estimator__C': 1, 'clf__estimator__intercept_scaling': 2, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9948 | Validation Score: 0.8157
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9912 | Validation Score: 0.8158
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 2, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9908 | Validation Score: 0.8158
#
# Params: {'clf__estimator__C': 1, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9948 | Validation Score: 0.8165
#
# Params: {'clf__estimator__C': 1, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9944 | Validation Score: 0.8157
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9908 | Validation Score: 0.8158
#
# Params: {'clf__estimator__C': 0.8, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9928 | Validation Score: 0.8188
#
# Params: {'clf__estimator__C': 0.8, 'clf__estimator__intercept_scaling': 2, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9924 | Validation Score: 0.8188
#
# Params: {'clf__estimator__C': 0.8, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9924 | Validation Score: 0.8172
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 20, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9872 | Validation Score: 0.8114
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9890 | Validation Score: 0.8297
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 2, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9890 | Validation Score: 0.8297
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9948 | Validation Score: 0.8365
#
# Params: {'clf__estimator__C': 1, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9946 | Validation Score: 0.8291
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 2, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9950 | Validation Score: 0.8365
#
# Params: {'clf__estimator__C': 0.8, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9918 | Validation Score: 0.8302
#
# Params: {'clf__estimator__C': 0.8, 'clf__estimator__intercept_scaling': 2, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9918 | Validation Score: 0.8297
#
# Params: {'clf__estimator__C': 0.8, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9918 | Validation Score: 0.8293
#
# Params: {'clf__estimator__C': 0.8, 'clf__estimator__intercept_scaling': 2, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9900 | Validation Score: 0.8703
#
# Params: {'clf__estimator__C': 0.8, 'clf__estimator__intercept_scaling': 10, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 4, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9898 | Validation Score: 0.8707
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9884 | Validation Score: 0.8724
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 2, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9884 | Validation Score: 0.8724
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 0.75, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9814 | Validation Score: 0.8942
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 2, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9814 | Validation Score: 0.8944
#
# Params: {'clf__estimator__C': 0.6, 'clf__estimator__intercept_scaling': 2, 'clf__estimator__max_iter': 800, 'tfidf__max_df': 0.9, 'tfidf__max_features': 7500, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 3)}
# Train Score: 0.9739 | Validation Score: 0.9040
#
# Best Validation Score: 0.9039917282864786

# %%
# export model
joblib.dump((best_estimator_2, label_encoder), '/content/drive/MyDrive/notebook_data/exports/models/linearsvc/linsvc_model_encoder_no_stopwords_nofeatures.pkl')
# Out:
# ['/content/drive/MyDrive/notebook_data/exports/models/linearsvc/linsvc_model_encoder_no_stopwords.pkl']
